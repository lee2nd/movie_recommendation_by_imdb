# %%
import pandas as pd
import gc

# %%
chunksize = 100_000  # 每次讀10萬筆

# 建立空 list 收集符合條件的資料
filtered_chunks = []

for chunk in pd.read_csv("title.basics.tsv.gz", sep='\t', dtype=str, na_values='\\N', chunksize=chunksize):
    chunk = chunk[(chunk['titleType'] == 'movie') & (chunk['startYear'].notna())]
    
    # 有些 startYear 非數字，轉換時需處理
    chunk = chunk[chunk['startYear'].str.isnumeric()]
    chunk['startYear'] = chunk['startYear'].astype(int)
    filtered_chunks.append(chunk)

# 合併所有過濾後的 chunk
basics_filtered = pd.concat(filtered_chunks, ignore_index=True)
print(f"載入後共有 {len(basics_filtered)} 筆符合條件的電影")
# Out:
# 載入後共有 613862 筆符合條件的電影

# %%
basics_filtered
# Out:
#            tconst titleType  \
# 0       tt0000009     movie
# 1       tt0000147     movie
# 2       tt0000502     movie
# 3       tt0000574     movie
# 4       tt0000591     movie
# ...           ...       ...
# 613857  tt9916622     movie
# 613858  tt9916680     movie
# 613859  tt9916706     movie
# 613860  tt9916730     movie
# 613861  tt9916754     movie
#
#                                              primaryTitle  \
# 0                                              Miss Jerry
# 1                           The Corbett-Fitzsimmons Fight
# 2                                                Bohemios
# 3                             The Story of the Kelly Gang
# 4                                        The Prodigal Son
# ...                                                   ...
# 613857        Rodolpho Teóphilo - O Legado de um Pioneiro
# 613858  De la ilusión al desconcierto: cine colombiano...
# 613859                                    Dankyavar Danka
# 613860                                             6 Gunn
# 613861                     Chico Albuquerque - Revelações
#
#                                             originalTitle isAdult  startYear  \
# 0                                              Miss Jerry       0       1894
# 1                           The Corbett-Fitzsimmons Fight       0       1897
# 2                                                Bohemios       0       1905
# 3                             The Story of the Kelly Gang       0       1906
# 4                                       L'enfant prodigue       0       1907
# ...                                                   ...     ...        ...
# 613857        Rodolpho Teóphilo - O Legado de um Pioneiro       0       2015
# 613858  De la ilusión al desconcierto: cine colombiano...       0       2007
# 613859                                    Dankyavar Danka       0       2013
# 613860                                             6 Gunn       0       2017
# 613861                     Chico Albuquerque - Revelações       0       2013
#
#        endYear runtimeMinutes                      genres
# 0          NaN             45                     Romance
# 1          NaN            100      Documentary,News,Sport
# 2          NaN            100                         NaN
# 3          NaN             70  Action,Adventure,Biography
# 4          NaN             90                       Drama
# ...        ...            ...                         ...
# 613857     NaN             57                 Documentary
# 613858     NaN            100                 Documentary
# 613859     NaN            NaN                      Comedy
# 613860     NaN            116                       Drama
# 613861     NaN             49                 Documentary
#
# [613862 rows x 9 columns]

# %%
# 載入評分資料
ratings = pd.read_csv("title.ratings.tsv.gz", sep='\t', dtype={'tconst': str})

# %%
ratings
# Out:
#             tconst  averageRating  numVotes
# 0        tt0000001            5.7      2164
# 1        tt0000002            5.5       296
# 2        tt0000003            6.5      2219
# 3        tt0000004            5.3       190
# 4        tt0000005            6.2      2959
# ...            ...            ...       ...
# 1589960  tt9916846            5.8         6
# 1589961  tt9916848            5.8         6
# 1589962  tt9916850            5.8         6
# 1589963  tt9916852            5.8         6
# 1589964  tt9916880            7.7        10
#
# [1589965 rows x 3 columns]

# %%
# 只取需要的欄位
basics_cols = ['tconst', 'primaryTitle', 'originalTitle', 'startYear', 'genres']

# left join，把電影資訊串進來
result = pd.merge(
    ratings,
    basics_filtered[basics_cols],
    on='tconst',
    how='inner'  # 只保留有評分的電影
)

# 顯示結果
result
# Out:
#            tconst  averageRating  numVotes                   primaryTitle  \
# 0       tt0000009            5.4       227                     Miss Jerry
# 1       tt0000147            5.3       563  The Corbett-Fitzsimmons Fight
# 2       tt0000502            3.6        22                       Bohemios
# 3       tt0000574            6.0      1006    The Story of the Kelly Gang
# 4       tt0000591            5.4        33               The Prodigal Son
# ...           ...            ...       ...                            ...
# 332488  tt9916362            6.4      6078                          Coven
# 332489  tt9916428            4.7        22            The Secret of China
# 332490  tt9916538            7.6        12            Kuambil Lagi Hatiku
# 332491  tt9916706            7.7         9                Dankyavar Danka
# 332492  tt9916730            7.0        13                         6 Gunn
#
#                         originalTitle  startYear                      genres
# 0                          Miss Jerry       1894                     Romance
# 1       The Corbett-Fitzsimmons Fight       1897      Documentary,News,Sport
# 2                            Bohemios       1905                         NaN
# 3         The Story of the Kelly Gang       1906  Action,Adventure,Biography
# 4                   L'enfant prodigue       1907                       Drama
# ...                               ...        ...                         ...
# 332488                       Akelarre       2020               Drama,History
# 332489   Hong xing zhao yao Zhong guo       2019       Adventure,History,War
# 332490            Kuambil Lagi Hatiku       2019                       Drama
# 332491                Dankyavar Danka       2013                      Comedy
# 332492                         6 Gunn       2017                       Drama
#
# [332493 rows x 7 columns]

# %%
del ratings
del basics_filtered
gc.collect()
# Out:
# 0

# %%
result = result[(result['numVotes']>1500) & (result['averageRating']>6.5)]
result = result.drop(columns=['tconst', 'originalTitle'])
result
# Out:
#         averageRating  numVotes                               primaryTitle  \
# 62                7.0      3854                            Dante's Inferno
# 99                6.9      2646  Fantômas: In the Shadow of the Guillotine
# 108               7.0      1542                              Ingeborg Holm
# 111               6.9      1796                 Fantomas: The Man in Black
# 175               7.1      4190                                    Cabiria
# ...               ...       ...                                        ...
# 332358            6.6      3373                               Mogul Mowgli
# 332379            6.8      2421                         Min pappa Marianne
# 332416            8.4     47492                                     Kaithi
# 332419            7.0      5163                                    Herself
# 332464            7.4      3480                        The Marriage Escape
#
#         startYear                   genres
# 62           1911  Adventure,Drama,Fantasy
# 99           1913              Crime,Drama
# 108          1913                    Drama
# 111          1913              Crime,Drama
# 175          1914  Adventure,Drama,History
# ...           ...                      ...
# 332358       2020              Drama,Music
# 332379       2020             Comedy,Drama
# 332416       2019    Action,Crime,Thriller
# 332419       2020                    Drama
# 332464       2020             Comedy,Drama
#
# [17224 rows x 5 columns]

# %%
result.to_csv("raw_imdb.csv", index=False)
